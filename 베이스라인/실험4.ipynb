# %% [markdown]
# # 디렉토리 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/DataSet/KYR_B_imaging.zip
# !cp '/content/drive/MyDrive/Colab Notebooks/프로젝트/ct분류/init.py' ./
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: KYR_B_imaging/20210910 임승이/2100037360020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100052160020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100098160020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100175960020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100388760020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100392260020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100525760020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210063210020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100669060020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100859960020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210096440020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/2100987460020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210121770020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210125950020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210128820020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210153450020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210185840020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210191360020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210219000020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/210231160020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/860034920020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8700247970020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870029110020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870173580020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870195530020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8704213470020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705302690020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8705568170020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870569870020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706033700020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/870668700020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8706739940020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880005060020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8800186090020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880243290020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8803116330020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/880368640020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8804095170020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8807321560020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8808161120020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340004.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340005.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340006.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340007.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340008.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340009.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340010.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340011.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340012.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340013.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340014.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340015.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340016.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340017.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340018.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340019.jpg
#   inflating: KYR_B_imaging/20210910 임승이/8900757340020.jpg
#   inflating: KYR_B_imaging/20210910 임승이/890208230001.jpg
#   inflating: KYR_B_imaging/20210910 임승이/890208230002.jpg
#   inflating: KYR_B_imaging/20210910 임승이/890208230003.jpg
#   inflating: KYR_B_imaging/20210910 임승이/890208230004.jpg
# ...
#   inflating: KYR_B_imaging/20220204 나윤수/960662840015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/960662840016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/960662840017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/960662840018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/960662840019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/960662840020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970009180020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970060890020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/970640010020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980004020020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980007710020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980142580020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980163580020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/980756330020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990170360020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600021.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600022.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600023.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600024.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990616600025.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990668680020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990715580020.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910001.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910002.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910003.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910004.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910005.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910006.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910007.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910008.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910009.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910010.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910011.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910012.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910013.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910014.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910015.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910016.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910017.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910018.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910019.jpg
#   inflating: KYR_B_imaging/20220204 나윤수/990910910020.jpg

# %%
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr3' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr2 74' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr5' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr1' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr7' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr8' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr4' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/nswr1' '/content/KYR_B_imaging' 
# !cp -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱/swr6' '/content/KYR_B_imaging' 
# !rm -r '/content/KYR_B_imaging/20201224 DL_MRI_SNSB_임승욱'

# %% [markdown]
# # 초기작업
# - 데이터 제너레이터에 넣을 수 있는 기본형태를 만드는 것

# %% [markdown]
# ## 기본 DF 생성
# - csv 데이터인 snsb_df
# - 이미지 디렉토리 관련인 dir_df만듬
#
# 전처리 과정에서
# - snsb_df -> csvs
# - dir_df -> new_dir_df로 변환 함

# %%
import os 
import cv2 
import pandas as pd 
from glob import glob
from tqdm import tqdm
from init import init #초기 설정용 커스텀 패키지 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.pyplot as cm 
import warnings
warnings.filterwarnings('ignore')
from albumentations import (
    Rotate,Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate,JpegCompression
)

# %% [markdown]
# ###snsb_df 생성
# - 환자 정보 데이터 프레임

# %%
columns = ['성명',
 '병록번호',
 '만나이',
 '검사일',
 '교육년수',
 'SVLT_recall_total_score_z',
 'SVLT_Delayed_recall_z',
 'SVLT_recognition_score_z',
 'RCFT_immediate_recall_z',
 'RCFT_delayed_recall_z',
 'RCFT_recognition_score_z',
 'K_MMSE_total_score_z',
 'SNSB_II_Domain_Attention_z',
 'SNSB_II_Domain_Language_z',
 'SNSB_II_Domain_Visuospatial_z',
 'SNSB_II_Domain_Memory_z',
 'SNSB_II_Domain_Frontal_z']

snsb_df = pd.read_csv('/content/drive/MyDrive/DataSet/202202_김예림/SNSB_integerated.csv')
snsb_df = snsb_df.drop([2098,2591]) #병록번호 없는 행 제거 <- 결측치 
snsb_df['병록번호'] = snsb_df['병록번호'].apply(lambda x : str(int(x))) #소수점으로 되어 있는 것 처리하고 str형 변형 

snsb_df = snsb_df[columns]


## 결측치 처리 

#컬럼 중 isnull 검색 
#검색한 표본들의 평균 나이 
#평균 나이로 원래  csvs 검색 
#해당 나이로 검색 된 것들의 평균 값으로 insull 채움 

null_columns = ['RCFT_immediate_recall_z',
                'SVLT_recall_total_score_z',
                'SVLT_Delayed_recall_z',
                'SVLT_recognition_score_z',
'RCFT_delayed_recall_z',            
'RCFT_recognition_score_z',        
'K_MMSE_total_score_z',           
'SNSB_II_Domain_Attention_z',       
'SNSB_II_Domain_Language_z',        
'SNSB_II_Domain_Visuospatial_z',    
'SNSB_II_Domain_Memory_z',          
'SNSB_II_Domain_Frontal_z']         

for null_column in null_columns:
  try:
    null_age = int(np.mean(snsb_df[snsb_df[null_column].isnull()]['만나이']))
    null_value = np.mean(snsb_df[snsb_df['만나이']==null_age][null_column].dropna())
    snsb_df.loc[snsb_df[null_column].isnull(),null_column] = null_value
  except:
    pass

# %% [markdown]
# ###dir_df 생성
# - 환자  별 mri 디렉토리 데이터 프레임
# - 이미지 장수 정리 안된 데이터 프레임

# %%
#폴더 디렉토리
folder_dir = glob('/content/KYR_B_imaging/*')
dir_df = init.dir_df(folder_dir)
dir_df = dir_df.sort_values(by=['key','dir'])
dir_df = dir_df.reset_index().drop(columns = 'index')

# %% [markdown]
# ### 병록번호- key 값 보정
# - 병록번호 == key 하게 만들어야 함 -> primary key
# - 중복 제거, @@@-1 형태 제거, 9자리로 통일

# %%
target_length = [4,5,6,7,8] #<- 수정해야 하는 병록번호 갯수들 

dir_df,snsb_df = init.key_mismatch(dir_df,snsb_df,target_length)
#인덱스 초기화 
dir_df = dir_df.reset_index().drop(columns = 'index')
# plt.hist(snsb_df['병록번호'].map(len))
# plt.show()

#에러값들 제외 
errors = ['000758836-1' '030338456-1' '040145556-1' '050236926-1' '090374796-1'
 '100402746-1' '120010356-1' '870133669-1' '920033543-1' '930236559-1'
 '930257597-1' '970682600-1']

dir_df = dir_df.drop(np.where(dir_df['key'].map(len)>9)[0])

# %% [markdown]
# ## new_dir_df 생성 - 이미지 장수 통일
# - 위에서 만든 dir_df에서 각 key 별로 이미지 19장으로 맞춤
# - 19장으로 맞추는 이유는 가장 비율이 높아서

# %% [markdown]
# ### key 값 별 이미지 장수 연산

# %%
#이미지 장수 연산 
keys = list(set(dir_df['key'])) 
images_length = pd.DataFrame(keys)[0].apply(lambda x: init.check_images(dir_df,x)) #키 값별로 이미지의 장수들 계산 
# images_length.value_counts()

length_df = pd.DataFrame([keys,images_length]).T
length_df.columns = ['key','image_length']
length_df['image_length']  = length_df['image_length'].map(int)

#Standard를 기준으로 less over 분할 
standard = 19 # 통일 시킬 이미지 장 수 기준 

# 조정이 필요한 장 수 초과하는 것들만 추림 
length_df_over = length_df[length_df['image_length']>standard]

#19장 보다 적은 경우 
# length_df_less = length_df[length_df['image_length']<standard]

len(length_df_over)
# Out:
# 1606

# %% [markdown]
# ### key값 별로 이미지 19장 있는 new_dir_df 생성

# %%
new_dir_df = pd.DataFrame(np.zeros(len(length_df_over)*19*2).reshape(-1,2))
new_dir_df.columns = dir_df.columns

for index in tqdm(range(len(length_df_over))):
  new_dir_df.iloc[index*19:(index+1)*19,:]  = dir_df.loc[init.droped_indexes(dir_df,length_df_over,index,standard=19)]
new_dir_df = new_dir_df.sort_values(by=['key','dir'])
new_dir_df = new_dir_df.reset_index().drop(columns = 'index')
# Out:
# 100%|██████████| 1606/1606 [00:07<00:00, 201.11it/s]

# %% [markdown]
# ## csvs 생성
#  - 중복 제거
#  - z score -1.0를 기준으로 0(정상) 1(비정상)으로 분류

# %%
#19장의 사진으로 추린 new_dir_df로 새로운 키 리스트만듬) 

key_lists = np.unique(new_dir_df['key'])
key_lists.sort()

Embedding_columns = snsb_df.columns[5:]

for column in Embedding_columns:
  snsb_df[f'E_{column}'] = snsb_df[column].map(init.zscore_Embedding)

#정렬 
snsb_df = snsb_df.sort_values(by=['병록번호'])
new_dir_df = new_dir_df.sort_values(by=['key','dir'])

#snsb_df 중 key_lists에 있는 행들만 추림 -> csvs 
csvs = snsb_df[snsb_df['병록번호'].apply(lambda x : x in key_lists)].sort_values(by=['병록번호'])
csvs = csvs.reset_index().drop(columns = 'index')

#중복 제거 : 이름으로 정렬 후 중복 제거 
csvs = csvs.sort_values(by=['성명'])
csvs = csvs.drop_duplicates(['병록번호'], keep = 'first')

#다시 병록번호 로 정렬 해서 csvs 와 new_dir_df 순을 맞춤 
csvs = csvs.sort_values(['병록번호'])
csvs = csvs.reset_index().drop(columns = 'index')
new_dir_df = new_dir_df.sort_values(by=['key','dir'])
new_dir_df = new_dir_df.reset_index().drop(columns = 'index')

#맞춤 확인 
print(len(csvs),len(np.unique(new_dir_df['key'])))
# Out:
# 1606 1606

# %% [markdown]
# # 전처리

# %% [markdown]
# ## Augmentation

# %%
import albumentations as A
transform = A.Compose([
    RandomBrightness(limit=0.1),
    JpegCompression(quality_lower=85, 
                    quality_upper=100, p=0.5), 
    HueSaturationValue(hue_shift_limit=20,
                        sat_shift_limit=30, 
                    val_shift_limit=20, p=0.5),
    RandomContrast(limit=0.2, p=0.5),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
])

# %% [markdown]
# ## 이미지 전처리

# %%
def plot_img(temp_img):
  plt.figure(figsize=(10,10))
  plt.imshow(temp_img)
  plt.show()

# %%
#이미지 전처리 

def img_preprocess(img):
  shape = img.shape[0]
  preprocessed_img = img[int(shape*0.05):int(shape*0.95),int(shape*0.1):int(shape*0.9),:] #crop 
  preprocessed_img = transform(image=preprocessed_img)['image']
  preprocessed_img = cv2.cvtColor(preprocessed_img,cv2.COLOR_BGR2GRAY)
  preprocessed_img = cv2.resize(preprocessed_img,dsize=(image_size,image_size)) #resize Albu mentations -> vision 관련 augmentation document 
  preprocessed_img = preprocessed_img/255.
  return preprocessed_img 


def key_to_dir(key,new_dir_df):
  dir_of_key = new_dir_df[new_dir_df['key']==key]
  return dir_of_key



def read_imgs(img_dir_df): #224, 224, 19 용 
  temp_imgs = np.zeros(image_size*image_size*image_channels).reshape(image_size,image_size,image_channels)
  for i in range(len(img_dir_df)):
    temp_img = img_dir_df['dir'].iloc[i]
    temp_img = img_preprocess(cv2.imread(temp_img))
    temp_imgs[:,:,i] = temp_img 
  return temp_imgs

# %% [markdown]
# # 데이터 제너레이터

# %% [markdown]
# ## 사전설정

# %%
input_columns = ['만나이','교육년수']
output_columns = ['E_SVLT_recall_total_score_z', 'E_SVLT_Delayed_recall_z',
       'E_SVLT_recognition_score_z', 'E_RCFT_immediate_recall_z',
       'E_RCFT_delayed_recall_z', 'E_RCFT_recognition_score_z',
       'E_K_MMSE_total_score_z', 'E_SNSB_II_Domain_Attention_z',
       'E_SNSB_II_Domain_Language_z', 'E_SNSB_II_Domain_Visuospatial_z',
       'E_SNSB_II_Domain_Memory_z', 'E_SNSB_II_Domain_Frontal_z']
output_column = 'SVLT_recall_total_score_z'


image_size = 256
image_channels = 19 
BATCH_SIZE= 32

# %% [markdown]
# ## !!!제너레이터

# %% [markdown]
# 키 리스트를 이용해 train, valid, test 분리

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import Sequence
import math


class DataGenerator(Sequence):
  def __init__(self,
                 new_dir_df,
                 csvs,
                 key_lists,
                 output_column,
                 batch_size: int,
                 augmentation: bool = False,
                 shuffle: bool = False,
                 rescale:bool = True) -> None:
        self.input_columns = input_columns 
        self.key_lists = key_lists
        self.output_columns = output_column
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augmentation = augmentation
        self.rescale =rescale
        self.new_dir_df = new_dir_df
        self.csvs = csvs

  def __len__(self):
    return math.ceil(len(self.key_lists) / self.batch_size)
    
  def on_epoch_end(self):
    self.indices = np.arange(len(self.key_lists))
    if self.shuffle == True:
      np.random.shuffle(self.indices)
      self.key_lists = self.key_lists[self.indices]
      



  def __getitem__(self, index):
    self.batch_keys = self.key_lists[index*self.batch_size:(index+1)*self.batch_size]
    self.batch_keys.sort()

    #imgs 
    temp_imgs = []
    for key in range(len(self.batch_keys)):
      img_dir_df = key_to_dir(self.batch_keys[key],self.new_dir_df)
      temp_img = read_imgs(img_dir_df)
      temp_imgs.append(temp_img)
    input_imgs = np.array(temp_imgs).astype(np.float)

    #input_csvs
    temp_csvs = self.csvs[self.csvs['병록번호'].apply(lambda x: x in self.batch_keys)]
    temp_csvs = temp_csvs.sort_values(by=['병록번호'])
    temp_csvs = temp_csvs.reset_index().drop(columns='index')
    input_csvs = temp_csvs[input_columns]
    input_csvs = (np.array(input_csvs)-csvs_input_min)/(csvs_input_max-csvs_input_min)
    input_csvs = np.array(input_csvs)

    #output_csvs
    temp_csvs = self.csvs[self.csvs['병록번호'].apply(lambda x: x in self.batch_keys)]
    temp_csvs = temp_csvs.sort_values(by=['병록번호'])
    temp_csvs = temp_csvs.reset_index().drop(columns='index')
    output_csvs = temp_csvs[self.output_columns]
    output_csvs = np.array(output_csvs)
    output_csvs = (output_csvs - csvs_output_0_min)/(csvs_output_0_max-csvs_output_0_min).astype(np.float)

    return [input_imgs,input_csvs],output_csvs
    # return input_imgs,output_csvs

# %% [markdown]
# #모델

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.metrics import Recall
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Activation, AveragePooling2D,ConvLSTM1D
from tensorflow.keras.layers import BatchNormalization,Conv2D,MaxPooling2D,Activation,Dropout,Dense,Flatten,Input,Conv3D,MaxPooling3D
from tensorflow.keras.layers import Conv3D, ConvLSTM2D, BatchNormalization, Input, Dropout, Bidirectional, Conv1D, MaxPooling1D,Reshape
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate
from tensorflow.keras.applications import resnet50, efficientnet,VGG19,EfficientNetV2S, NASNetLarge, ResNet50V2, vgg19,resnet_v2,efficientnet_v2
from tensorflow.keras.applications import ResNet50, EfficientNetB0, DenseNet169, MobileNet,EfficientNetB4, ResNet152V2, EfficientNetV2B0
import math
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from keras.layers.pooling import GlobalAveragePooling2D,GlobalAveragePooling3D,AveragePooling3D
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers.schedules import CosineDecay, ExponentialDecay

# %% [markdown]
# ## !!!모델 사전 정의

# %%
res50 = ResNet50V2(weights='imagenet', include_top=False, input_shape=(image_size, image_size,3)) #size -> 256, 256 
res50.trainable = False

vgg_19 = VGG19(weights='imagenet', include_top=False, input_shape=(image_size, image_size,3)) #size -> 256, 256 
vgg_19.trainable = False

effv2 = EfficientNetV2S(weights='imagenet', include_top=False, input_shape=(image_size, image_size,3)) #size -> 256, 256 
effv2.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 2s 0us/step
# 94683136/94668760 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# 80150528/80134624 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82427904/82420632 [==============================] - 1s 0us/step
# 82436096/82420632 [==============================] - 1s 0us/step

# %%
def input_to_pre(image_input): #224,224,19
  x = Conv2D(16, (2,2), padding ='same',activation = 'relu')(image_input)
  x = BatchNormalization()(x)
  x = Dropout(0.2)(x)
  x = Conv2D(8, (2,2), padding ='same',activation = 'relu')(x)
  x = BatchNormalization()(x)
  x = Dropout(0.2)(x)
  x = Conv2D(4, (2,2), padding ='same',activation = 'relu')(x)
  x = BatchNormalization()(x)
  x = Dropout(0.2)(x)
  out = Conv2D(3, (2,2), padding ='same',activation = 'relu')(x)
  return out 

def image_encoder_layer(filters,img_input):
  img = Conv2D(filters,(3,3),padding='same')(img_input)
  img = Dropout(0.2)(img)
  img_output = BatchNormalization()(img)
  return img_output


def image_encoder(image_combined):
  # img = image_encoder_layer(1024,image_combined)
  # img = image_encoder_layer(512,image_combined)
  # img = image_encoder_layer(256,image_combined)
  img_out = image_encoder_layer(128,image_combined)
  return img_out

def csvs_layers(filters,csv_input):
  csv = Dense(filters, activation = 'relu')(csv_input)
  csv = Dropout(0.2)(csv)
  csv_layer_out = BatchNormalization()(csv)
  return csv_layer_out

def csvs_decoder(csvs_input):
  # csvs = csvs_layers(32,csvs_input)
  # csvs = csvs_layers(64,csvs)
  csvs_out = csvs_layers(128,csvs_input)
  return csvs_out

# %% [markdown]
# ## 콜백

# %%
# copy from https://gist.github.com/stared/dfb4dfaf6d9a8501cd1cc8b8cb806d2e
# loss 실시간 출력 
from IPython.display import clear_output
from tensorflow.keras.callbacks import Callback

class PlotLosses(Callback):

  def on_train_begin(self, logs={}):
    self.epochs = []
    self.losses = []
    self.val_losses = []
    self.logs = []
    self.fig = plt.figure()


  def on_epoch_end(self, epoch, logs={}):

    self.epochs.append(epoch)
    self.losses.append(logs.get('loss'))
    self.val_losses.append(logs.get('val_loss'))

    clear_output(wait=True)
    plt.plot(self.epochs, self.losses, label="loss")
    plt.plot(self.epochs, self.val_losses, label="val_loss")
    plt.legend()
    plt.show();
    print("loss = ", self.losses[-1], ", val_loss = ", self.val_losses[-1])

#call backs 선언
plot_losses = PlotLosses()

from tensorflow.keras.callbacks import ModelCheckpoint #<- model 저장 객체, best_model.h5라는 모델 이 저장 됨 
model_check_point = ModelCheckpoint(
    'best_model.h5', 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True)


from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',  # 모니터링 대상, 이걸 기준으로 멈춤 
    verbose=1,
    patience=20)         # 중지까지의 여유분

from tensorflow.keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', # 모니터링 대상
    patience=10,        # 대상ㅃ 기간동안 유지
    factor=0.2,         # 줄이는 양                              
    min_learning_rate=0.00001)     # 최소 학습율

callbacks = [ plot_losses]

# %% [markdown]
# ## !!!모델

# %%
#image input 
def make_model():
  image_input = Input((image_size,image_size,19))
  image = input_to_pre(image_input)

  # conv 
  res = resnet_v2.preprocess_input(image)
  res = res50(res)
  res = image_encoder(res)

  vgg = vgg19.preprocess_input(image)
  vgg = vgg_19(vgg)
  vgg = image_encoder(vgg)

  eff = efficientnet_v2.preprocess_input(image)
  eff = effv2(eff)
  eff = image_encoder(eff)

  # image combined 
  image_combined = concatenate([res,vgg,eff])
  image_combined = Conv2D(128, (2,2), padding = 'same')(image_combined)
  image_out = GlobalAveragePooling2D()(image_combined)


  #csv 
  csvs_input = Input((2))
  csvs_out = csvs_decoder(csvs_input)


  #image csv combined 
  combined = concatenate([image_out,csvs_out])

  #out 
  out = Dense(1,activation='sigmoid')(combined)

  model = Model([image_input,csvs_input],out)
  return model

# %% [markdown]
# ## !!!Compile - Train

# %%
# !pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.0 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

# %%
optimizer = tfa.optimizers.RectifiedAdam(
    lr=1e-3,
    total_steps=10000,
    warmup_proportion=0.1,
    min_lr=1e-5,
)

# %% [markdown]
# ## Cross validation

# %%
output_column = 'SVLT_recall_total_score_z'

input_columns = ['만나이','교육년수']

def minmax(index,out_column):
  scaling_value = np.array(csvs[out_column].iloc[index])
  min = np.min(scaling_value,axis=0)
  max = np.max(scaling_value,axis=0)
  return max,min

# %%
model_lists = []
history_lists = []
np.random.shuffle(key_lists)

#Stratified Kfold indexing 용 
test_index = np.arange(1446,1606)
x = key_indexes = np.arange(1445)
y = np.array(csvs[output_columns[0]][:1445])

#Stratified Kfold 
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(x, y)
for train_index, valid_index in skf.split(x, y):

  #minmax scaling 용 
  csvs_input_max, csvs_input_min = minmax(train_index,input_columns)
  csvs_output_0_max,csvs_output_0_min = minmax(train_index, output_column)

  #제너레이터 
  train_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[train_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                  shuffle=True)
  valid_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[valid_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                shuffle=False)
  test_generator = DataGenerator(new_dir_df,
                               csvs,
                               key_lists[test_index],
                               output_column,
                               batch_size=BATCH_SIZE,
                               shuffle=False)
  model = make_model()
  model.compile(optimizer=optimizer,loss = 'mse',metrics=['mae'])
  history = model.fit(train_generator,validation_data = valid_generator, epochs=50,verbose=1,callbacks=callbacks)
  
  model_lists.append(model)
  history_lists.append(history)
  #Batch : 32 + output : 0 + isize:256 + Radam + init : 0.001 + Expo decay + s Kfold
# Out:
# loss =  0.015220047906041145 , val_loss =  0.019736142829060555
# 37/37 [==============================] - 451s 12s/step - loss: 0.0152 - mae: 0.0984 - val_loss: 0.0197 - val_mae: 0.1106
# Epoch 25/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0156 - mae: 0.0993

# %% [markdown]
# # Test 평가

# %%
def descaling(value):
  origin = value*(csvs_output_0_max-csvs_output_0_min) + csvs_output_0_min
  return origin
def temp(value):
  if value >=-1:
    return 0 
  else:
    return 1 
def score_regression_predict(model,generator,index):
  y_ = model.predict(generator)
  predicted = pd.DataFrame(y_)[0].map(descaling)
  y_predicted = predicted.map(temp)
  from sklearn.metrics import classification_report

  y_true = np.array(csvs[csvs['병록번호'].apply(lambda x : x in key_lists[index])][output_columns[0]])
  print(classification_report(y_true,y_predicted,target_names = ['0','1']))

# %% [markdown]
# ## Train

# %%
test_index = np.arange(1446,1606)
x = key_indexes = np.arange(1445)
y = np.array(csvs[output_columns[0]][:1445])

predicted_train_lists = [] 

from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(x, y)
n = 0 
for train_index, valid_index in skf.split(x, y):
  train_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[train_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                  shuffle=True)
  valid_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[valid_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                shuffle=False)
  test_generator = DataGenerator(new_dir_df,
                               csvs,
                               key_lists[test_index],
                               output_column,
                               batch_size=BATCH_SIZE,
                               shuffle=False)
  model = model_lists[n]
  y_ = model.predict(train_generator)
  
  predicted = pd.DataFrame(y_)[0].map(descaling)
  predicted_train_lists.append(predicted)


  y_predicted = predicted.map(temp)
  from sklearn.metrics import classification_report
  y_true = np.array(csvs[csvs['병록번호'].apply(lambda x : x in key_lists[train_index])][output_columns[0]])
  print(classification_report(y_true,y_predicted,target_names = ['0','1']))
  true_1 = np.where(y_true==1)
  true_0 = np.where(y_true==0)

  plt.figure(figsize=(10,3))
  plt.hist(predicted.iloc[true_1],color='r',alpha=0.5)
  plt.hist(predicted.iloc[true_0],color='b',alpha=0.5)
  plt.show()
  n+=1

# %% [markdown]
# ## Valid

# %%
test_index = np.arange(1446,1606)
x = key_indexes = np.arange(1445)
y = np.array(csvs[output_columns[0]][:1445])

predicted_valid_lists = [] 

from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(x, y)
n = 0 
for train_index, valid_index in skf.split(x, y):

  train_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[train_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                  shuffle=True)
  valid_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[valid_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                shuffle=False)
  test_generator = DataGenerator(new_dir_df,
                               csvs,
                               key_lists[test_index],
                               output_column,
                               batch_size=BATCH_SIZE,
                               shuffle=False)
  model = model_lists[n]
  y_ = model.predict(valid_generator)
  predicted = pd.DataFrame(y_)[0].map(descaling)

  predicted_valid_lists.append(predicted)



  y_predicted = predicted.map(temp)
  from sklearn.metrics import classification_report
  y_true = np.array(csvs[csvs['병록번호'].apply(lambda x : x in key_lists[valid_index])][output_columns[0]])
  print(classification_report(y_true,y_predicted,target_names = ['0','1']))
  true_1 = np.where(y_true==1)
  true_0 = np.where(y_true==0)

  plt.figure(figsize=(10,3))
  plt.hist(predicted.iloc[true_1],color='r',alpha=0.5)
  plt.hist(predicted.iloc[true_0],color='b',alpha=0.5)
  plt.show()
  n+=1

# %% [markdown]
# ## Test

# %%
test_index = np.arange(1446,1606)
x = key_indexes = np.arange(1445)
y = np.array(csvs[output_columns[0]][:1445])

predicted_test_lists = []

from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(x, y)
n = 0 
for train_index, valid_index in skf.split(x, y):

  train_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[train_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                  shuffle=True)
  valid_generator = DataGenerator(new_dir_df,
                                csvs,
                                key_lists[valid_index],
                                output_column,
                                batch_size=BATCH_SIZE,
                                shuffle=False)
  test_generator = DataGenerator(new_dir_df,
                               csvs,
                               key_lists[test_index],
                               output_column,
                               batch_size=BATCH_SIZE,
                               shuffle=False)
  model = model_lists[n]
  y_ = model.predict(test_generator)
  predicted = pd.DataFrame(y_)[0].map(descaling)
  predicted_test_lists.append(predicted)

  y_predicted = predicted.map(temp)
  from sklearn.metrics import classification_report
  y_true = np.array(csvs[csvs['병록번호'].apply(lambda x : x in key_lists[test_index])][output_columns[0]])
  print(classification_report(y_true,y_predicted,target_names = ['0','1']))
  true_1 = np.where(y_true==1)
  true_0 = np.where(y_true==0)

  plt.figure(figsize=(10,3))
  plt.hist(predicted.iloc[true_1],color='r',alpha=0.5)
  plt.hist(predicted.iloc[true_0],color='b',alpha=0.5)
  plt.show()
  n+=1

# %%
for i in range(5):
  plt.plot(history_lists[i].history['loss'])
  plt.plot(history_lists[i].history['val_loss'])
  plt.show()

# %% [markdown]
# # 실험

# %%
vote = np.average(E_predicted.iloc[:1445,:5],axis=1)
plt.hist(vote[true_0],color='b',alpha=0.5)
plt.hist(vote[true_1],color='r',alpha=0.5)
plt.show()

# %% [markdown]
# # Save

# %%
test_index = np.arange(1446,1606)
x = key_indexes = np.arange(1445)
y = np.array(csvs[output_columns[0]][:1445])
E_predicted = pd.DataFrame(np.zeros(1606*15).reshape(1606,15))

from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(x, y)
n = 0 

for train_index, valid_index in skf.split(x, y):
  E_predicted.iloc[train_index,n] = np.array(predicted_train_lists)[n,:]
  E_predicted.iloc[valid_index,n+5] = np.array(predicted_valid_lists)[n,:]
  E_predicted.iloc[test_index,n+10] = np.array(predicted_test_lists)[n,:]
  n+=1
# E_predicted.to_csv('Ex1_predicted.csv')

# %%
for i in range(len(model_lists)):
  model = model_lists[i]
  model.save(f'Ex_1_{i}.h5')
  model.save_weights(f'Ex_1_{i}_weight')

# %%
# !cp 'Ex1_predicted.csv' '/content/drive/MyDrive/DataSet/mri_model/실험1'


# !cp 'Ex_1_0.h5' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_0_weight.data-00000-of-00001' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_0_weight.index' '/content/drive/MyDrive/DataSet/mri_model/실험1'

# !cp 'Ex_1_1.h5' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_1_weight.data-00000-of-00001' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_1_weight.index' '/content/drive/MyDrive/DataSet/mri_model/실험1' 

# !cp 'Ex_1_2.h5'	'/content/drive/MyDrive/DataSet/mri_model/실험1'	    
# !cp 'Ex_1_2_weight.data-00000-of-00001' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_2_weight.index' '/content/drive/MyDrive/DataSet/mri_model/실험1'

# !cp 'Ex_1_3.h5' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_3_weight.data-00000-of-00001' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_3_weight.index' '/content/drive/MyDrive/DataSet/mri_model/실험1'

  
# !cp 'Ex_1_4.h5' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_4_weight.data-00000-of-00001' '/content/drive/MyDrive/DataSet/mri_model/실험1'
# !cp 'Ex_1_4_weight.index' '/content/drive/MyDrive/DataSet/mri_model/실험1'

# %%
# !pip list
